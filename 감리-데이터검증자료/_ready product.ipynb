# %%
import pandas as pd
import numpy as np
import os
from os import listdir

import scipy.stats as ss
import math

# %%
# TU_VC_ABILITY_EVL

z_00 = 'C:/Users/Admin/Desktop/MediaBigdata_20201120/products/TU_VC_ABILITY_EVL/year=2020/month=10/day=01/HYU_TU_VC_ABILITY_EVL_20201001194905.csv'
z_00 = pd.read_csv(z_00, header=0, sep=",")
z_00.tail()
# Out:
#           ABILITY_EVL_CHNNL_ID ABILITY_EVL_CHNNL_NM ABILITY_EVL_COLCT_DE  \
# 2665  UC_jNan0EvSTUNKT2dj6U31A                  피큐큐           2020-10-01
# 2666  UC9SZ7d8YtD4C_zWuGCoNM7A             JET 1004           2020-10-01
# 2667  UCzC0CyJV8KwRDA0JKevQKng                 스무고개           2020-10-01
# 2668  UC1wjdW8A3HSQMoQeu79-yLw    한국항공우주연구원 KARI TV           2020-10-01
# 2669  UCr1YT5IRw3iI1oQgbBOpWrQ                보고싶진아           2020-10-01
#
#                                    ABILITY_EVL_CHNNL_DC  \
# 2665     친근한 동네 형 같은 마성의 매력 삐뀨뀪  문의 - pqq@sandbox.co.kr
# 2666                                                NaN
# 2667  스무살 혹은 그 언저리의 고민들!  스무고개가 들어줄게요 :)   스무와 함께해요!...
# 2668  KARI 한국항공우주연구원은 대한민국 항공우주 분야 중심 연구기관으로서 항공우주기술...
# 2669  진아의 일상 영상이 업로드됩니다! 비즈니스 문의 : bogoshipjina@sand...
#
#      ABILITY_EVL_CHNNL_CREAT_DE ABILITY_ACCTO_GROUP_ASGN  GROUP_ISE_CHNNL_CO  \
# 2665                 2015-06-09                    MACRO                1443
# ...

# %%
z_00.isnull().sum()
# Out:
# ABILITY_EVL_CHNNL_ID               0
# ABILITY_EVL_CHNNL_NM               0
# ABILITY_EVL_COLCT_DE               0
# ABILITY_EVL_CHNNL_DC             414
# ABILITY_EVL_CHNNL_CREAT_DE         0
# ABILITY_ACCTO_GROUP_ASGN           0
# GROUP_ISE_CHNNL_CO                 0
# GROUP_ISE_READER_RANK              0
# GROUP_ISE_RDCNT_RANK               0
# GROUP_ISE_ILKT_RANK                0
# ABILITY_EVL                        0
# PR_IDEX                          634
# RECENT_SIX_MONTH                 897
# FRST_SIX_MONTH                  1175
# INTRC_DGREE_ONE_MONTH              0
# GROUP_ISE_PR_IDEX_STD_SCORE      634
# RECENT_SIX_MONTH_STD_SCORE       257
# FRST_SIX_MONTH_STD_SCORE          11
# INTRC_DO_ONE_MONTH_STD_SCORE       0
# dtype: int64

# %%
# TU_VC_GROWTH_IDEX

z_01 = 'C:/Users/Admin/Desktop/MediaBigdata_20201120/products/TU_VC_GROWTH_IDEX/year=2020/month=10/day=01/HYU_TU_VC_GROWTH_IDEX_20201001193707.csv'
z_01 = pd.read_csv(z_01, header=0, sep=",")
z_01.tail()
# Out:
#         GROWTH_IDEX_VIDO_ID GROWTH_IDEX_VIDO_CTGRY GROWTH_IDEX_VIDO_DC  \
# 2033244         v7WVOSNOmCI                반려동물/동물                 NaN
# 2033245         iiALwOVqnAk                반려동물/동물                 NaN
# 2033246         iiALwOVqnAk                반려동물/동물                 NaN
# 2033247         18AvxrQVzSU                반려동물/동물                 NaN
# 2033248         18AvxrQVzSU                반려동물/동물                 NaN
#
#         GROWTH_IDEX_VIDO_LT                GROWTH_IDEX_VIDO_SJ  \
# 2033244             PT2M43S         파충익광고) 한국에만 존재하는 법의 실체는??!
# 2033245             PT2M31S  6750만원 소녀가 전달한 도마뱀의 주인을 찾습니다...!!
# 2033246             PT2M31S  6750만원 소녀가 전달한 도마뱀의 주인을 찾습니다...!!
# 2033247             PT6M16S           선물 클라스ㅋㅋ 타란튤라들을 왕창 받아버렸네
# 2033248             PT6M16S           선물 클라스ㅋㅋ 타란튤라들을 왕창 받아버렸네
#
#              GROWTH_IDEX_CHNNL_ID GROWTH_IDEX_CHNNL_NM GROWTH_IDEX_COLCT_DE  \
# 2033244  UCwl9OALh8IMwSv_kFdHlMDA                  다흑님           2020-10-01
# ...

# %%
# TU_VC_IMPRVMDGREE_IDEX

z_02 = 'C:/Users/Admin/Desktop/MediaBigdata_20201120/products/TU_VC_IMPRVMDGREE_IDEX/year=2020/month=10/day=01/HYU_TU_VC_IMPRVMDGREE_IDEX_20201001194308.csv'
z_02 = pd.read_csv(z_02, header=0, sep=",")
z_02.tail()
# Out:
#      IMPRVMDGREE_IDEX_CHNNL_ID IMPRVMDGREE_IDEX_CHNNL_NM  \
# 2665  UC_jNan0EvSTUNKT2dj6U31A                       피큐큐
# 2666  UC9SZ7d8YtD4C_zWuGCoNM7A                  JET 1004
# 2667  UCzC0CyJV8KwRDA0JKevQKng                      스무고개
# 2668  UC1wjdW8A3HSQMoQeu79-yLw         한국항공우주연구원 KARI TV
# 2669  UCr1YT5IRw3iI1oQgbBOpWrQ                     보고싶진아
#
#      IMPRVMDGREE_IDEX_COLCT_DE  \
# 2665                2020-10-01
# 2666                2020-10-01
# 2667                2020-10-01
# 2668                2020-10-01
# 2669                2020-10-01
#
#                               IMPRVMDGREE_IDEX_CHNNL_DC  \
# 2665     친근한 동네 형 같은 마성의 매력 삐뀨뀪  문의 - pqq@sandbox.co.kr
# 2666                                                NaN
# 2667  스무살 혹은 그 언저리의 고민들!  스무고개가 들어줄게요 :)   스무와 함께해요!...
# 2668  KARI 한국항공우주연구원은 대한민국 항공우주 분야 중심 연구기관으로서 항공우주기술...
# 2669  진아의 일상 영상이 업로드됩니다! 비즈니스 문의 : bogoshipjina@sand...
#
#      IMPRVMDGREE_CHNNL_CREAT_DE  RECENT_SIX_MONTH_IMPRVMDGREE  \
# ...

# %%
# TU_VC_INTRC_IDEX

z_03 = 'C:/Users/Admin/Desktop/MediaBigdata_20201120/products/TU_VC_INTRC_IDEX/year=2020/month=10/day=01/HYU_TU_VC_INTRC_IDEX_20201001194305.csv'
z_03 = pd.read_csv(z_03, header=0, sep=",")
z_03.tail()
# Out:
#            INTRC_IDEX_CHNNL_ID INTRC_IDEX_CHNNL_NM INTRC_IDEX_COLCT_DE  \
# 2665  UC_jNan0EvSTUNKT2dj6U31A                 피큐큐          2020-10-01
# 2666  UC9SZ7d8YtD4C_zWuGCoNM7A            JET 1004          2020-10-01
# 2667  UCzC0CyJV8KwRDA0JKevQKng                스무고개          2020-10-01
# 2668  UC1wjdW8A3HSQMoQeu79-yLw   한국항공우주연구원 KARI TV          2020-10-01
# 2669  UCr1YT5IRw3iI1oQgbBOpWrQ               보고싶진아          2020-10-01
#
#                                     INTRC_IDEX_CHNNL_DC  \
# 2665     친근한 동네 형 같은 마성의 매력 삐뀨뀪  문의 - pqq@sandbox.co.kr
# 2666                                                NaN
# 2667  스무살 혹은 그 언저리의 고민들!  스무고개가 들어줄게요 :)   스무와 함께해요!...
# 2668  KARI 한국항공우주연구원은 대한민국 항공우주 분야 중심 연구기관으로서 항공우주기술...
# 2669  진아의 일상 영상이 업로드됩니다! 비즈니스 문의 : bogoshipjina@sand...
#
#      INTRC_IDEX_CHNNL_CREAT_DE      IDEX_ALL  IDEX_ONE_MONTH  \
# 2665                2015-06-09  6.000750e+11       4106946.0
# 2666                2019-05-25  2.170000e+02             0.0
# ...

# %%
# TU_VC_POLICY_ISSUE_FMNM_IDEX

z_04 = 'C:/Users/Admin/Desktop/MediaBigdata_20201120/products/TU_VC_POLICY_ISSUE_FMNM_IDEX/year=2020/month=10/day=01/HYU_TU_VC_POLICY_ISSUE_FMNM_IDEX_20201001193619.csv'
z_04 = pd.read_csv(z_04, header=0, sep=",")
z_04.tail()
# Out:
#                        CHNNL_ID      CHNNL_NM   COLCT_DAY  \
# 34459  UCg7rkxrTnIhiHEpXY1ec9NA         잠뜰 TV  2020-10-01
# 34460  UC2fsxQr6Hcx1enORxXgKpxQ  Jane ASMR 제인  2020-10-01
# 34461  UCYvFbXyku5PaYw3CUwqGRzg          허니또♥  2020-10-01
# 34462  UCsDD9Vn9wfsEHJFRu7sHxLA      서대문구청유튜브  2020-10-01
# 34463  UCC0hHIP7cqZZWNgKa1Ni9iw      SUWON·수원  2020-10-01
#
#                                                       DC   CREAT_DAY KWRD  \
# 34459  잠뜰의 유튜브 YouTube 채널에 오신 것을 환영합니다! 구독하기 버튼과 알림 버...  2014-05-22   주식
# 34460  ASMR 리얼사운드 먹방 채널입니다. 영상은 매일 업로드 합니다.  Welcome ...  2012-11-17   청년
# 34461  허니또버전의 피아노연주를 들려드리는 공간입니다.   KPOP POP  OST  CC...  2016-04-30   대회
# 34462    안녕하세요. 서대문구청 공식 유튜브 채널입니다. 함께 소통하고 공유하는 공간입니다^^  2012-02-27   창업
# 34463  수원을 한눈에 만날 수 있는 수원시 공식 유튜브 채널  수원시 공식 유튜브 채널은 ...  2011-02-23  광주시
#
#        KWRD_FQ  KWRD_IPCR
# 34459        1      1.796
# 34460        4      4.900
# 34461        1      0.794
# 34462        8     13.478
# 34463        1      3.534

# %%
# TU_VC_POPULAR_IDEX

z_05 = 'C:/Users/Admin/Desktop/MediaBigdata_20201120/products/TU_VC_POPULAR_IDEX/year=2020/month=10/day=01/HYU_TU_VC_POPULAR_IDEX_20201001193658.csv'
z_05 = pd.read_csv(z_05, header=0, sep=",")
z_05.tail()
# Out:
#          POPULAR_IDEX_CHNNL_ID POPULAR_IDEX_CHNNL_NM POPULAR_IDEX_COLCT_DE  \
# 2665  UC_jNan0EvSTUNKT2dj6U31A                   피큐큐            2020-10-01
# 2666  UC9SZ7d8YtD4C_zWuGCoNM7A              JET 1004            2020-10-01
# 2667  UCzC0CyJV8KwRDA0JKevQKng                  스무고개            2020-10-01
# 2668  UC1wjdW8A3HSQMoQeu79-yLw     한국항공우주연구원 KARI TV            2020-10-01
# 2669  UCr1YT5IRw3iI1oQgbBOpWrQ                 보고싶진아            2020-10-01
#
#                                   POPULAR_IDEX_CHNNL_DC  \
# 2665     친근한 동네 형 같은 마성의 매력 삐뀨뀪  문의 - pqq@sandbox.co.kr
# 2666                                                NaN
# 2667  스무살 혹은 그 언저리의 고민들!  스무고개가 들어줄게요 :)   스무와 함께해요!...
# 2668  KARI 한국항공우주연구원은 대한민국 항공우주 분야 중심 연구기관으로서 항공우주기술...
# 2669  진아의 일상 영상이 업로드됩니다! 비즈니스 문의 : bogoshipjina@sand...
#
#      POPULAR_IDEX_CHNNL_CREAT_DE  \
# 2665                  2015-06-09
# 2666                  2019-05-25
# 2667                  2019-01-24
# 2668                  2011-11-25
# ...

# %%
# TU_VC_PR_IDEX

z_06 = 'C:/Users/Admin/Desktop/MediaBigdata_20201120/products/TU_VC_PR_IDEX/year=2020/month=10/day=01/HYU_TU_VC_PR_IDEX_20201001194256.csv'
z_06 = pd.read_csv(z_06, header=0, sep=",")
z_06.tail()
# Out:
#               PR_IDEX_CHNNL_ID   PR_IDEX_CHNNL_NM PR_IDEX_COLCT_DE  \
# 2665  UC_jNan0EvSTUNKT2dj6U31A                피큐큐       2020-10-01
# 2666  UC9SZ7d8YtD4C_zWuGCoNM7A           JET 1004       2020-10-01
# 2667  UCzC0CyJV8KwRDA0JKevQKng               스무고개       2020-10-01
# 2668  UC1wjdW8A3HSQMoQeu79-yLw  한국항공우주연구원 KARI TV       2020-10-01
# 2669  UCr1YT5IRw3iI1oQgbBOpWrQ              보고싶진아       2020-10-01
#
#                                        PR_IDEX_CHNNL_DC CHNNL_CREAT_DAY  \
# 2665     친근한 동네 형 같은 마성의 매력 삐뀨뀪  문의 - pqq@sandbox.co.kr      2015-06-09
# 2666                                                NaN      2019-05-25
# 2667  스무살 혹은 그 언저리의 고민들!  스무고개가 들어줄게요 :)   스무와 함께해요!...      2019-01-24
# 2668  KARI 한국항공우주연구원은 대한민국 항공우주 분야 중심 연구기관으로서 항공우주기술...      2011-11-25
# 2669  진아의 일상 영상이 업로드됩니다! 비즈니스 문의 : bogoshipjina@sand...      2016-12-15
#
#       OUTPUT_CO  PR_IDEX_READER_CO  TOT_RDCNT  TOT_ILKT_CO  TOT_NLKT_CO  ...  \
# ...

# %%
# TU_VC_REACH_IDEX

z_07 = 'C:/Users/Admin/Desktop/MediaBigdata_20201120/products/TU_VC_REACH_IDEX/year=2020/month=10/day=01/HYU_TU_VC_REACH_IDEX_20201001194311.csv'
z_07 = pd.read_csv(z_07, header=0, sep=",")
z_07.tail()
# Out:
#         REACH_IDEX_VIDO_ID REACH_IDEX_VIDO_CTGRY REACH_IDEX_VIDO_DC  \
# 2033244        v7WVOSNOmCI               반려동물/동물                NaN
# 2033245        iiALwOVqnAk               반려동물/동물                NaN
# 2033246        iiALwOVqnAk               반려동물/동물                NaN
# 2033247        18AvxrQVzSU               반려동물/동물                NaN
# 2033248        18AvxrQVzSU               반려동물/동물                NaN
#
#         REACH_IDEX_VIDO_LT                 REACH_IDEX_VIDO_SJ  \
# 2033244            PT2M43S         파충익광고) 한국에만 존재하는 법의 실체는??!
# 2033245            PT2M31S  6750만원 소녀가 전달한 도마뱀의 주인을 찾습니다...!!
# 2033246            PT2M31S  6750만원 소녀가 전달한 도마뱀의 주인을 찾습니다...!!
# 2033247            PT6M16S           선물 클라스ㅋㅋ 타란튤라들을 왕창 받아버렸네
# 2033248            PT6M16S           선물 클라스ㅋㅋ 타란튤라들을 왕창 받아버렸네
#
#               REACH_IDEX_CHNNL_ID REACH_IDEX_CHNNL_NM REACH_IDEX_COLCT_DE  \
# 2033244  UCwl9OALh8IMwSv_kFdHlMDA                 다흑님          2020-10-01
# ...

# %%
z_0.isnull().sum()

# %%
len(z_0)

# %%
z_0 = 'C:/Users/Admin/Desktop/MediaBigdata_20201120/data/tf/year=2020/month=10/day=01/hour=17/tf.csv'
z_0 = pd.read_csv(z_0, header=0, sep=",")

# %%
z_0.tail()
