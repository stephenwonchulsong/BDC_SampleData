# %%
import pandas as pd
import numpy as np
import os
from os import listdir

import scipy.stats as ss
import math

# %%
# z_0 = 'C:/Users/admin/Desktop/_Media big data/____________10.07/Archive/exporter2/TU_VC_CHNNL_IDX_GR/year=2020/month=09/day=01/HYU_TU_VC_CHNNL_IDX_GR_20200901195713.csv'

#data #channel
z_0 = 'C:/Users/Admin/Desktop/MediaBigdata_20201120/data/channel/year=2020/month=10/day=01/hour=17/server_1.csv'
z_0 = pd.read_csv(z_0, header=0, sep="|")

# %%
z_0.tail()
# Out:
#                            id          title        collectedTime category  \
# 330  UCOnRjLVo8R3mp5QdM_IvWJQ           홍성군청  2020-10-01T17:40:52        P
# 331  UCMdk3e8PDrwJPYgJkGWTkOA      성수종합사회복지관  2020-10-01T17:40:52        P
# 332  UCNxpE9chB-7ATWwUbXPJAsw  광진구청소년지원센터꿈드림  2020-10-01T17:40:52        P
# 333  UC8QtI9Do6RHtatZYpYwq0MA  서울주얼리지원센터 제1관  2020-10-01T17:40:52        P
# 334  UCt6ExO7ld8X_kAjybR6p9mg       서울자전거따릉이  2020-10-01T17:40:52        P
#
#     sub_category                                        description  \
# 330          PCN                                                NaN
# 331          PSL  성수종합사회복지관은 성수 4개동(성수1가1동, 1가2동, 2가1동, 2가3동), 용...
# 332          PSL  광진구 청소년지원센터 꿈드림에 1인 미디어 동아리 띵크(Think)입니다. 미래의 ...
# 333          PSL  서울주얼리지원센터는 서울시 특화산업인 도심형 고부가가치 주얼리 산업의 활성화를 위한...
# 334          PSL                           서울 공공자전거 따릉이 사용방법 안내 동영상
#
#               publishedAt                                       thumbnailUrl  \
# ...
